# %% [markdown]
# <a href="https://colab.research.google.com/github/jwoo-park/ML-study/blob/main/Ch2_Statistical_Learning/Seo_yeon/hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ISLP import load_data

boston = load_data("Boston")

# %%
# a. How many rows are in this data set? How many columns? What do the rows and columns represent?
boston.info()

# rows: 506, columns: 13
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  lstat    506 non-null    float64
#  12  medv     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
# b. Make some pairwise scatterplots of the predictors (columns) in this data set.
# Describe your findings.

pd.plotting.scatter_matrix(boston, figsize=(16,16))
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
#         <Axes: xlabel='chas', ylabel='crim'>,
#         <Axes: xlabel='nox', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='ptratio', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='zn'>,
#         <Axes: xlabel='zn', ylabel='zn'>,
#         <Axes: xlabel='indus', ylabel='zn'>,
#         <Axes: xlabel='chas', ylabel='zn'>,
#         <Axes: xlabel='nox', ylabel='zn'>,
#         <Axes: xlabel='rm', ylabel='zn'>,
#         <Axes: xlabel='age', ylabel='zn'>,
#         <Axes: xlabel='dis', ylabel='zn'>,
# ...

# %%
# (c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

corr= boston.corr()

crim_corr = corr['crim'].sort_values(ascending=False)
print(crim_corr)

'''
positive correlation: rad(고속도로 접근성), tax(세율), lstst, nox, indus, age, ptratio
negative correlation: chas, zn, rm(방개수), dis(고용중심지 거리), mdv(집값)
Several predictors are associated with crime rate.
In particular, rad and tax have strong positive correlations with crim, while medv, rm, and dis have negative correlations,
indicating that higher-quality neighborhoods tend to have lower crime rates.
'''
# Out:
# crim       1.000000
# rad        0.625505
# tax        0.582764
# lstat      0.455621
# nox        0.420972
# indus      0.406583
# age        0.352734
# ptratio    0.289946
# chas      -0.055892
# zn        -0.200469
# rm        -0.219247
# dis       -0.379670
# medv      -0.388305
# Name: crim, dtype: float64

# %%
# (d) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios?
# Comment on the range of each predictor.

summary = boston.describe().T[['min', 'max']]
print(summary)

'''
Some suburbs exhibit extreme values in several predictors.
The crime rate (crim) ranges widely and includes some very high values, indicating the presence of outliers.
The tax rate (tax) also varies significantly across suburbs.
Similarly, the pupil-teacher ratio (ptratio) shows noticeable variation, suggesting differences in educational resources.
'''


plt.scatter.boston.(boston.['TAX'], boston.['CRIM'])
plt.xlabel('TAX')
plt.ylabel('CRIM')
plt.show()
# Out:
#   File "/tmp/ipykernel_249/3990474988.py", line 15
#     plt.scatter.boston.(boston.['TAX'], boston.['CRIM'])
#                        ^
# SyntaxError: invalid syntax

# %%
# (e) How many of the suburbs in this data set bound the Charles river?

count_chas = (boston['chas'] == 1).sum()
print(count_chas)

'''
chas = Charles River dummy variable
1 → river에 인접
0 → 인접 아님
ans: 35
'''
# Out:
# 35
# '\nchas = Charles River dummy variable\n1 → river에 인접\n0 → 인접 아님\nans: 35\n'

# %%
# (f) What is the median pupil-teacher ratio among the towns in this data set?

median_ptratio = boston['ptratio'].median()
print(median_ptratio)

'''
ans: 19.05
'''
# Out:
# 19.05

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
# (g) Which suburb of Boston has lowest median value of owner-occupied homes?
# What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors?
# Comment on your findings.

min_idx=boston['medv'].idxmin()
print("lowest medv suburb index:", min_idx)

a = boston.describe()
a.loc['range'] = a.loc['max'] - a.loc['min']

a.loc[min_idx] = boston.loc[min_idx]

print(a)

relative_pos = (boston.loc[min_idx] - a.loc['min']) / a.loc['range']
print("\n",relative_pos)
# Out:
# lowest medv suburb index: 398
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
# range   88.969880  100.000000   27.280000    1.000000    0.486000    5.219000
# 398     38.351800    0.000000   18.100000    0.000000    0.693000    5.453000
#
#               age         dis         rad         tax     ptratio       lstat  \
# ...

# %%
# (h) In this data set, how many of the suburbs average more than seven rooms per dwelling?
# More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

more_than_7 = (boston['rm'] > 7).sum()
more_than_8 = (boston['rm'] > 8).sum()

print("rm > 7:", more_than_7)
print("rm > 8:", more_than_8)

boston[boston['rm'] > 8]
# Out:
# rm > 7: 64
# rm > 8: 13
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...
